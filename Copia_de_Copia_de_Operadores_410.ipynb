# %% [markdown]
# <a href="https://colab.research.google.com/github/rosasguerrerozuleimayamileth-cell/Zuleima-Yamileth-Rosas-Guerrero-/blob/main/Copia_de_Copia_de_Operadores_410.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("...Operadores Matematicos...")
print("...Operacion de Suma 5 + 8 =" , 5 + 8)
print("...Operacion de Resta 9 - 7 =" , 9 - 7)
print("...Operacion de Multiplicacion 5 * 8=" , 5 * 8)
# Out:
# ...Operadores Matematicos...
# ...Operacion de Suma 5 + 8 = 13
# ...Operacion de Resta 9 - 7 = 2
# ...Operacion de Multiplicacion 5 * 8= 40

# %%
numero1 = 5
numero2 = 8
resultado = numero1 + numero2
print(resultado)
# Out:
# 13

# %%
print("OPERACIONES")
num1 = input("Ingresa el primer número: ")
num2 = input("Ingresa el segundo número: ")
suma = num1 + num2
print("La suma es:", suma)
# Out:
# OPERACIONES
# Ingresa el primer número: 5
# Ingresa el segundo número: 8
# La suma es: 58

# %%
b= 0
a= 0

if type(b) is not int:
  raise Exception("Error de Tipo - Uincamente se permiten enteros")

elif b == 0:
    print("No se puede dividir entre el cero")

else:
    print(a/b)
    print(a/b)
# Out:
# 0.25
# 0.25

# %%
a = float(input("Valor de a:"))
b = float(input("Valor de b:"))
x = -b/a
print("Respuesta: ", x)
# Out:
# Valor de a:4
# Valor de b:8
# Respuesta:  -2.0

# %%
a = float(input("Valor de a:"))
b = float(input("Valor de b:"))
if a !=0:
  x = -b/a
  print("Respuesta: ", x)

if a == 0:
  if b !=0:
    print("La Operación no se puede realizar")
  if b == 0:
    print("La operación puede tener varias opciones")
# Out:
# Valor de a:10
# Valor de b:8
# Respuesta:  -0.8

# %%
a = 50
b = 52
if a < b:
  print(a,"Es menor que", b)
elif a > b:
  print(a, "Es Mayor que", b)
else:
  print(a, "Es igual que", b)
# Out:
# 50 Es menor que 52

# %%
for i in (8, 5):
  if i % 2 == 0:
    print(f"{i} es par")
  else:
    print(f"{i} es impar")
# Out:
# 8 es par
# 5 es impar

# %%
secreto = 8
intento = 0

while intento != secreto:
  intento = int(input("Adivina el número: "))
  if intento < secreto:
    print(" Muy bajo")
  elif intento > secreto:
    print(" Muy Alto")

print("!Correcto¡")
# Out:
# Adivina el número: 5
#  Muy bajo
# Adivina el número: 9
#  Muy Alto
# Adivina el número: 8
# !Correcto¡

# %%
class cajero:
  def __init__(self, saldo_inicial):
if saldo_inicial > 10000:
self.saldo = saldo_inicial

else:
  print("El saldo debe ser mayor a $10,000")
  self.saldo = 10001
  print("se asigno $10,001 como saldo inicial")

def depositar(self, monto):
if monto <= 0:
   self.saldo += monto
   else:
    print("el monto debe ser mayor a 0")

def retirar(self, monto):
  if monto <= 0:
    print("El monto debe ser mayor a 0")
elif self.saldo - monto < 10000:
  print("No se puede retirar esa cantidad. ")
  else:
    self.saldo == Monto
    print(f"Retirar $(monto). Saldo actual: $(self.saldo)")

def mostrar_saldo(self):
saldo_inicial = float(input("Ingresa el saldo inicial: "))
cajero1 = cajero(saldo_inicial)

while True:
  print("1. Depositar")
  print("2. Retirar")
  print("3. Mostrar Saldo")
  print("4. Salir")

  opcion = input("Selecciona una opción: ")

if opcion == "1":
  saldo = float(input("Ingresa el monto a depositar: "))
  cuenta.depositar(cantidad)


elif opcion == "2":
  saldo = float_(input("Ingresa el monto a retirar: "))
  cuenta.retirar(cantidad)

elif opcion == "3":
  cuenta.mostrar_saldo()

elif opcion == "4":
  print("¡Hasta luego!")
  break

else:
  print("Opcion invalida. Por favor, selecciona una opcion valida.")
# Out:
#   File "/tmp/ipykernel_1034/2521308144.py", line 6
#     else:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 4
