# %%
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 + n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 + n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 + n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 + n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 + n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 + n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 + n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 + n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 + n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 + n2
print("el resultado es: ", r)
print("")
print("suma")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 - n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 - n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 - n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 - n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 - n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 - n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 - n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 - n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 - n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 - n2
print("el resultado es: ", r)
print("resta")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 * n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 * n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 * n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 * n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 * n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 * n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 * n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 * n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 * n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 * n2
print("el resultado es: ", r)
print("multiplicacion")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 / n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 / n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 / n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 / n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 / n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 / n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 / n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 / n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 / n2
print("el resultado es: ", r)
print("")
n1 = float(input("ingresa num1:"))
n2 = float(input("ingresa num2:"))
r = n1 / n2
print("el resultado es: ", r)
print("divicion")
# Out:
# ingresa num1:0
# ingresa num2:0
# el resultado es:  0.0
#
# ingresa num1:0
# ingresa num2:0
# el resultado es:  0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-838661798.py in <cell line: 0>()
#       9 print("el resultado es: ", r)
#      10 print("")
# ---> 11 n1 = float(input("ingresa num1:"))
#      12 n2 = float(input("ingresa num2:"))
#      13 r = n1 + n2
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...
